# %% [markdown]
# # Tuning an SVC Model
#
# copied from `xgb_fitting.ipynb`
#
# The goal of this notebook is to train and evaluate an SVC model, comparing it's performance on a holdout set against other types of models (LR,LDA, XGBoost).
#
# To ensure reproducibility and consistent evaluation across models, all datasets were **pre-split into cross-val data and holdout data** as below:
#
# | Split type           | CV training file     | Holdout file              | Description                              |
# | -------------------- | -------------------- | ------------------------- | ---------------------------------------- |
# | **Random**           | `apps_cv_random.csv` | `apps_holdout_random.csv` | Simple random sampling                   |
# | **Stratified**       | `apps_cv_strat.csv`  | `apps_holdout_strat.csv`  | Stratified by `TARGET`                   |
# | **Multi-Stratified** | `apps_cv_multi.csv`  | `apps_holdout_multi.csv`  | Stratified by `TARGET` + `CODE_GENDER_M` |
#
# Each dataset for cross-validation (`apps_cv_*.csv`) also contains a column, `fold`, with pre-assigned folds from 1-5 using the corresponding splitting method to ensure consistent evaluation. Therefore, no additional splitting is needed inside this notebook -- can simply loop through assigned folds for cross-validation.

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC
from sklearn.decomposition import PCA

# %% [markdown]
# Copied from `XGB_fitting.ipynb`

# %%
# METRICS 

def classification_metrics(y_true, y_pred):
    """
    Computes confusion matrix + accuracy, precision, recall, F1, and balanced accuracy.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    # Confusion matrix components
    tp = np.sum((y_true == 1) & (y_pred == 1))
    tn = np.sum((y_true == 0) & (y_pred == 0))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    fn = np.sum((y_true == 1) & (y_pred == 0))

    # Metrics
    acc  = (tp + tn) / max((tp + tn + fp + fn), 1)
    prec = tp / max((tp + fp), 1)
    rec  = tp / max((tp + fn), 1)
    f1   = (2 * prec * rec / max((prec + rec), 1e-12)) if (prec + rec) > 0 else 0.0

    # Specificity (True Negative Rate)
    spec = tn / max((tn + fp), 1)

    # Balanced accuracy
    bal_acc = 0.5 * (rec + spec)

    metrics = {
        "n": len(y_true),
        "tp": tp, "tn": tn, "fp": fp, "fn": fn,
        "acc": acc, "bal_acc": bal_acc, "prec": prec, "rec": rec, "spec": spec,
        "f1": f1
    }
    return metrics

def roc_auc_from_probs(y_true, y_prob):
    
    desc_sort_indices = np.argsort(-y_prob)
    y_true = np.array(y_true)[desc_sort_indices]
    y_prob = np.array(y_prob)[desc_sort_indices]
    pos = np.sum(y_true == 1)
    neg = np.sum(y_true == 0)

    # running totals for TPR/FPR
    tpr = [0.0]
    fpr = [0.0]
    tp = fp = 0
    for i in range(len(y_true)):
        if y_true[i] == 1:
            tp += 1
        else:
            fp += 1
        tpr.append(tp / pos)
        fpr.append(fp / neg)

    # get auc
    auc = np.trapz(tpr, fpr)
    return auc

def pr_auc_from_probs(y_true, y_prob):
    # Sort by predicted probability descending
    desc_sort_indices = np.argsort(-y_prob)
    y_true = np.array(y_true)[desc_sort_indices]
    y_prob = np.array(y_prob)[desc_sort_indices]
    
    tp = 0
    fp = 0
    pos = np.sum(y_true == 1)
    
    precision = [1.0]  # starts at 1 when recall=0
    recall = [0.0]
    
    for i in range(len(y_true)):
        if y_true[i] == 1:
            tp += 1
        else:
            fp += 1
        prec = tp / (tp + fp)
        rec = tp / pos
        precision.append(prec)
        recall.append(rec)
    
    # ensure it ends at recall=1
    precision = np.array(precision)
    recall = np.array(recall)
    
    # integrate area under curve
    auc_pr = np.trapz(precision, recall)
    return auc_pr

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

def cv_svc_pca(data, feature_cols, target_col, params=None, n_components=0.95):
    
    if params is None:
        params = {}
    params = {
        "dual": True,
        "class_weight": "balanced",
        **params
    }

    fold_metrics = []

    for f in sorted(data.fold.unique()):
        train = data[data.fold != f]
        test  = data[data.fold == f]
        X_train, y_train = train[feature_cols], train[target_col]
        X_test,  y_test  = test[feature_cols],  test[target_col]

        pipe = make_pipeline(
            StandardScaler(),
            PCA(n_components=n_components),
            LinearSVC(**params)
        )

        pipe.fit(X_train, y_train)

        y_pred = pipe.predict(X_test)
        y_scores = pipe.decision_function(X_test)
        y_train_scores = pipe.decision_function(X_train)
        # y_prob = pipe.predict_proba(X_test)
        # y_train_prob = pipe.predict_proba(X_train)

        m = classification_metrics(y_test, y_pred)
        m["roc_auc"]       = roc_auc_from_probs(y_test, y_scores)
        m["train_roc_auc"] = roc_auc_from_probs(y_train, y_train_scores)
        m["fold"] = int(f)
        fold_metrics.append(m)

    return pd.DataFrame(fold_metrics).sort_values("fold").reset_index(drop=True)

# %% [markdown]
# # Model Development
#
# **Notes:**
# - All evaluation will focus on stratified cross-validation, but we will test the other methods as well.
# - Recall that folds have been pre-assigned to ensure consistency across different model development processes
# - We have decided to scale + PCA.
#
# **Process:**
# 1. Setting a baseline
#     - evaluating an xgb model with all default parameters to build off of
# 2. Hyperparameter tuning
#     - evaluate many different combinations of parameters
#     - choose the best set based on average ROC-AUC across all folds
# 3. Holdout evaluation
#     - evaluate on the corresponding holdout table. the performance here is what we will compare with other models (LR, SVC, LDA)
# 4. Threshold tuning
#     - tweak the threshold on the best model to maximize another chosen metric (recall, precision, f1, balanced accuracy, etc.)
#         - note that roc-auc is not affected by threshold, hence the need a different optimizing metric
#     - what metric we choose to optimize with threshold depends on business needs
#         - consider the cost of mislabeling someone as high risk? or trusting an applicant that you shouldn't? will there be human review?
#         - something we can include in the right up as optionality moving forward, not something we have to decide now on our own
#         - "our model is very solid at ranking applicants from low-risk to high-risk, but in terms of actual classification, we can move the threshold based on what matters most to the business"

# %% [markdown]
# # setup

# %%
apps_cv_strat = pd.read_csv("data/apps_cv_strat.csv")
apps_holdout_strat = pd.read_csv("data/apps_holdout_strat.csv")
target_col = 'TARGET'
feature_cols = [col for col in apps_cv_strat.columns if col not in 
                [target_col, 'SK_ID_CURR', 'fold', 'neighbors_target_mean_500' , 'AGE_INT', 'DAYS_BIRTH', 'CODE_GENDER_M', 'CODE_GENDER_XNA', 'NAME_FAMILY_STATUS_Previously Married', 'NAME_FAMILY_STATUS_Single']]
print(sorted(feature_cols))
# Out:
# ['AMT_ANNUITY', 'AMT_CREDIT', 'AMT_GOODS_PRICE', 'AMT_INCOME_TOTAL', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'BUREAU_REQ_MISSING', 'BUREAU_REQ_TOTAL', 'CNT_CHILDREN', 'CNT_FAM_MEMBERS', 'DAYS_CREDIT_mean_external', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'DAYS_LAST_PHONE_CHANGE', 'DAYS_REGISTRATION', 'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'EMERGENCYSTATE_MODE_UNKNOWN', 'EMERGENCYSTATE_MODE_Yes', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'EXT_SOURCE_MEAN', 'FLAG_CONT_MOBILE', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_EMAIL', 'FLAG_EMP_PHONE', 'FLAG_MOBIL', 'FLAG_OWN_CAR_Y', 'FLAG_OWN_REALTY_Y', 'FLAG_PHONE', 'FLAG_WORK_PHONE', 'FONDKAPREMONT_MODE_Regional', 'FONDKAPREMONT_MODE_Unknown', 'HOUR_APPR_PROCESS_START', 'HOUSETYPE_MODE_Other', 'HOUSETYPE_MODE_Unknown', 'LIVE_CITY_NOT_WORK_CITY', 'LIVE_REGION_NOT_WORK_REGION', 'NAME_CONTRACT_TYPE_Revolving loans', 'NAME_EDUCATION_TYPE_Low', 'NAME_EDUCATION_TYPE_Secondary', 'NAME_HOUSING_TYPE_Parents', 'NAME_HOUSING_TYPE_Rent', 'NAME_INCOME_TYPE_Not working', 'NAME_INCOME_TYPE_Retired', 'NAME_INCOME_TYPE_Self-employed', 'NAME_TYPE_SUITE_Other', 'NAME_TYPE_SUITE_Unaccompanied', 'OBS_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'OCCUPATION_TYPE_Blue-collar', 'OCCUPATION_TYPE_Service', 'OCCUPATION_TYPE_Unknown', 'OCCUPATION_TYPE_White-collar', 'ORGANIZATION_TYPE_Culture', 'ORGANIZATION_TYPE_Industrial', 'ORGANIZATION_TYPE_Private', 'ORGANIZATION_TYPE_Public', 'ORGANIZATION_TYPE_Religion', 'ORGANIZATION_TYPE_Security', 'ORGANIZATION_TYPE_Unknown', 'OWN_CAR_AGE', 'PROPERTY_MISSING_PROP', 'REGION_POPULATION_RELATIVE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'SOCIAL_DEF_30_RATE', 'SOCIAL_DEF_60_RATE', 'SOCIAL_DEF_TOTAL', 'SOCIAL_OBS_TOTAL', 'WALLSMATERIAL_MODE_Panel', 'WALLSMATERIAL_MODE_Unknown', 'WALLSMATERIAL_MODE_Wood/Mixed/Other', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WEEKDAY_APPR_PROCESS_START_SATURDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'WEEKDAY_APPR_PROCESS_START_THURSDAY', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'active_loan_ratio_external', 'annuity_to_max_installment_ratio', 'avg_credit_amount_external', 'avg_credit_debt_external', 'avg_credit_debt_ratio_external', 'avg_credit_prolongs_external', 'avg_dpd_internal', 'avg_status_external', 'credit_annuity_ratio', 'credit_downpayment', 'credit_goods_price_ratio', 'debt_credit_ratio_external', 'ever_late_loan_ratio_external', 'has_any_history_all', 'inst_avg_days_diff_internal', 'inst_max_days_diff_internal', 'inst_max_instalment_internal', 'inst_min_days_diff_internal', 'inst_num_loans_internal', 'inst_pay_rate_internal', 'inst_prop_early_payments_internal', 'inst_prop_late_payments_internal', 'inst_sum_due_internal', 'inst_sum_paid_internal', 'inst_total_payments_internal', 'installment_payment_ratio_1000_mean_mean_internal', 'last_active_DAYS_CREDIT_external', 'loans_with_info_internal', 'most_recent_loan_active_external_Bad debt', 'most_recent_loan_active_external_Closed', 'most_recent_loan_active_external_Sold', 'most_recent_loan_active_external_group_Closed', 'most_recent_loan_active_external_group_Problematic', 'most_recent_loan_external', 'most_recent_loan_type_external_Car loan', 'most_recent_loan_type_external_Consumer credit', 'most_recent_loan_type_external_Credit card', 'most_recent_loan_type_external_Loan for business development', 'most_recent_loan ...

# %%
params = {}
results = cv_svc_pca(apps_cv_strat, feature_cols, target_col, params=params)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
results
# Out:
#        n    tp     tn    fp    fn       acc   bal_acc      prec       rec  \
# 0  49156  1662  39535  5652  2307  0.838087  0.646833  0.227235  0.418745
# 1  49156  1987  37169  8018  1982  0.796566  0.661595  0.198601  0.500630
# 2  49156  1839  37662  7525  2130  0.803585  0.648405  0.196390  0.463341
# 3  49155  1994  37395  7791  1975  0.801322  0.664986  0.203781  0.502394
# 4  49154  1935  37294  7892  2033  0.798084  0.656498  0.196906  0.487651
#
#        spec        f1   roc_auc  train_roc_auc  fold
# 0  0.874920  0.294602  0.734349       0.734456     1
# 1  0.822560  0.284385  0.739607       0.735101     2
# 2  0.833470  0.275857  0.725445       0.740305     3
# 3  0.827579  0.289952  0.743978       0.741105     4
# 4  0.825344  0.280536  0.734690       0.736279     5

# %%
from itertools import product
import time

def grid_search_SVC(data, feature_cols, target_col, param_grid):
    
    # get all possible combinations of parameters
    keys = list(param_grid.keys())
    combos = [dict(zip(keys, v)) for v in product(*param_grid.values())]

    # initialize stuff for tracking and results
    results = []
    total = len(combos)
    start = time.time()
    next_checkpoint = 5 
    best_roc_auc = 0
    best_params = None

    # evaluate every possible combo
    for i, params in enumerate(combos, 1):

        # run cross validation and store results
        fold_results = cv_svc_pca(data, feature_cols, target_col, params)
        mean_roc_auc = fold_results["roc_auc"].mean()

        results.append({
            'params': params,
            'mean_roc_auc': mean_roc_auc,
            'mean_f1': fold_results['f1'].mean(),
            'mean_acc': fold_results['acc'].mean(),
            'mean_bal_acc': fold_results['bal_acc'].mean(),
            'mean_prec': fold_results['prec'].mean(),
            'mean_rec': fold_results['rec'].mean(),
        })

        # tracker for updates
        if  mean_roc_auc > best_roc_auc:
            best_roc_auc =  mean_roc_auc
            best_params = params

        # print progress checkpoints
        pct_done = (i/total)*100
        elapsed = time.time() - start
        if pct_done >= next_checkpoint or i == total:
            print(f"{i}/{total} ({pct_done:5.1f}% in {elapsed/60:.1f} mins) | Best ROC-AUC: {best_roc_auc:.4f} | Best Params: {best_params}")
            next_checkpoint += 5


    
    return pd.DataFrame(results).sort_values("mean_roc_auc", ascending=False).reset_index(drop=True)

# %%
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100],
    "loss": ["hinge", "squared_hinge"]
}

wide_search_results = grid_search_SVC(apps_cv_strat, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1/12 (  8.3% in 1.0 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/12 ( 16.7% in 8.4 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/12 ( 25.0% in 11.0 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.01, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 4/12 ( 33.3% in 18.3 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.01, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/12 ( 41.7% in 23.8 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/12 ( 50.0% in 31.0 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 7/12 ( 58.3% in 37.4 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/12 ( 66.7% in 44.7 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/12 ( 75.0% in 51.9 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 10/12 ( 83.3% in 59.1 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/12 ( 91.7% in 66.5 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/12 (100.0% in 73.8 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.1, 'loss': 'hinge'}

# %%
wide_search_results
# Out:
#                                    params  mean_roc_auc   mean_f1  mean_acc  \
# 0             {'C': 0.1, 'loss': 'hinge'}      0.753527  0.265728  0.698556
# 1     {'C': 0.1, 'loss': 'squared_hinge'}      0.753480  0.266677  0.701555
# 2            {'C': 0.01, 'loss': 'hinge'}      0.753447  0.265690  0.698723
# 3    {'C': 0.01, 'loss': 'squared_hinge'}      0.753357  0.265717  0.697917
# 4           {'C': 0.001, 'loss': 'hinge'}      0.753259  0.265232  0.697226
# 5   {'C': 0.001, 'loss': 'squared_hinge'}      0.753234  0.265612  0.697551
# 6               {'C': 1, 'loss': 'hinge'}      0.745827  0.266079  0.707475
# 7       {'C': 1, 'loss': 'squared_hinge'}      0.731704  0.280578  0.801096
# 8      {'C': 10, 'loss': 'squared_hinge'}      0.606105  0.124352  0.867762
# 9     {'C': 100, 'loss': 'squared_hinge'}      0.589194  0.108899  0.876880
# 10            {'C': 100, 'loss': 'hinge'}      0.572506  0.116667  0.857941
# 11             {'C': 10, 'loss': 'hinge'}      0.563744  0.105082  0.876799
#
#     mean_bal_acc  mean_prec  mean_rec
# 0       0.688072   0.165395  0.675570
# 1       0.688140   0.166339  0.672143
# 2       0.687933   0.165396  0.675066
# 3       0.688368   0.165301  0.676981
# 4       0.687923   0.164936  0.676830
# 5       0.688376   0.165193  0.677434
# 6       0.684305   0.166877  0.656673
# 7       0.653681   0.199121  0.477878
# 8       0.531312   0.138993  0.130068
# 9       0.521904   0.141792  0.098568
# 10      0.524129   0.121259  0.126034
# 11      0.519332   0.128750  0.093026

# %%
powers = np.arange(-3, -1, 0.1)
grid_values = [10**x for x in powers]

param_grid = {
    "C": grid_values,
    "loss": ["hinge"]
}

search_results2 = grid_search_SVC(apps_cv_strat, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1/20 (  5.0% in 1.0 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/20 ( 10.0% in 2.0 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.0012589254117941675, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/20 ( 15.0% in 3.0 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.001584893192461114, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 4/20 ( 20.0% in 4.2 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.0019952623149688807, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/20 ( 25.0% in 5.4 mins) | Best ROC-AUC: 0.7533 | Best Params: {'C': 0.002511886431509582, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/20 ( 30.0% in 6.8 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.0031622776601683824, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 7/20 ( 35.0% in 8.4 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.003981071705534978, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/20 ( 40.0% in 10.1 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.00501187233627273, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/20 ( 45.0% in 12.1 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.006309573444801942, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 10/20 ( 50.0% in 14.3 mins) | Best ROC-AUC: 0.7534 | Best Params: {'C': 0.00794328234724283, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/20 ( 55.0% in 16.8 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.010000000000000021, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/20 ( 60.0% in 19.7 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.012589254117941701, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 13/20 ( 65.0% in 22.8 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.015848931924611172, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 14/20 ( 70.0% in 26.3 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.01995262314968885, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 15/20 ( 75.0% in 30.2 mins) | Best ROC-AUC: 0.7535 | Best Params: {'C': 0.01995262314968885, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 16/20 ( 80.0% in 34.4 mins) | Best ROC-AUC: 0.7536 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 17/20 ( 85.0% in 39.2 mins) | Best ROC-AUC: 0.7536 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 18/20 ( 90.0% in 44.2 mins) | Best ROC-AUC: 0.7536 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 19/20 ( 95.0% in 49.4 mins) | Best ROC-AUC: 0.7536 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 20/20 (100.0% in 54.9 mins) | Best ROC-AUC: 0.7536 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}

# %%
search_results2
# Out:
#                                            params  mean_roc_auc   mean_f1  \
# 0     {'C': 0.03162277660168389, 'loss': 'hinge'}      0.753587  0.265601
# 1     {'C': 0.01995262314968885, 'loss': 'hinge'}      0.753518  0.265682
# 2     {'C': 0.03981071705534985, 'loss': 'hinge'}      0.753513  0.265819
# 3    {'C': 0.015848931924611172, 'loss': 'hinge'}      0.753502  0.265716
# 4    {'C': 0.025118864315095874, 'loss': 'hinge'}      0.753499  0.265712
# 5     {'C': 0.06309573444801955, 'loss': 'hinge'}      0.753489  0.265758
# 6    {'C': 0.012589254117941701, 'loss': 'hinge'}      0.753484  0.265838
# 7     {'C': 0.07943282347242846, 'loss': 'hinge'}      0.753480  0.265624
# 8    {'C': 0.010000000000000021, 'loss': 'hinge'}      0.753473  0.265706
# 9      {'C': 0.0501187233627274, 'loss': 'hinge'}      0.753434  0.265550
# 10    {'C': 0.00794328234724283, 'loss': 'hinge'}      0.753434  0.265707
# 11   {'C': 0.006309573444801942, 'loss': 'hinge'}      0.753402  0.265660
# 12    {'C': 0.00501187233627273, 'loss': 'hinge'}      0.753398  0.265668
# 13   {'C': 0.003981071705534978, 'loss': 'hinge'}      0.753367  0.265520
# 14  {'C': 0.0031622776601683824, 'loss': 'hinge'}      0.753353  0.265605
# 15   {'C': 0.002511886431509582, 'loss': 'hinge'}      0.753330  0.265639
# 16  {'C': 0.0019952623149688807, 'loss': 'hinge'}      0.753299  0.265600
# 17   {'C': 0.001584893192461114, 'loss': 'hinge'}      0.753290  0.265493
# 18  {'C': 0.0012589254117941675, 'loss': 'hinge'}      0.753275  0.265399
# 19                  {'C': 0.001, 'loss': 'hinge'}      0.753258  0.265225
#
#     mean_acc  mean_bal_acc  mean_prec  mean_rec
# 0   0.698759      0.687769   0.165351  0.674663
# 1   0.698731      0.687915   0.165393  0.675015
# 2   0.698943      0.688030   0.165499  0.675015
# 3   0.698808      0.687934   0.165422  0.674965
# 4   0.698869      0.687898   0.165428  0.674814
# 5   0.698654      0.688079   0.165424  0.675469
# 6   0.698861      0.688100   0.165499  0.675267
# 7   0.698918      0.687741   0.165386  0.674411
# 8   0.698678      0.687978   0.165399  0.675217
# 9   0.698711      0.687720   0.165315  0.674612
# 10  0.698613      0.688011   0.165391  0.675368
# 11  0.698515      0.687981   0.165351  0.675419
# 12  0.698438      0.688031   0.165345  0.675620
# 13  0.698300      0.687864   0.165243  0.675419
# 14  0.698275      0.688012   0.165288  0.675771
# 15  0.698169      0.688115   0.165293  0.676124
# 16  0.698064      0.688103   0.165256  0.676225
# 17  0.697852      0.688034   0.165167  0.676326
# 18  0.697575      0.688022   0.165077  0.676628
# 19  0.697213      0.687917   0.164930  0.676830

# %% [markdown]
# We found the best value of `C` to be 10^-1.5

# %% [markdown]
# # Holdout Evaluation

# %%
# make train and test sets
train = apps_cv_strat
test = apps_holdout_strat
X_train, y_train = train[feature_cols], train[target_col]
X_test,  y_test  = test[feature_cols],  test[target_col]

# set up pipeline with scaling, PCA, and SVC
pipe = make_pipeline(
    StandardScaler(),
    PCA(n_components=0.95),
    LinearSVC(C=10**-1.5, loss="hinge", dual=True, class_weight="balanced")
)

# fit and predict
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
y_scores = pipe.decision_function(X_test)
y_train_scores = pipe.decision_function(X_train)

# get metrics
m = classification_metrics(y_test, y_pred)
m["roc_auc"]       = roc_auc_from_probs(y_test, y_scores)
m["train_roc_auc"] = roc_auc_from_probs(y_train, y_train_scores)
m["pr_roc_auc"] = pr_auc_from_probs(y_test, y_scores)
m
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# {'n': 61443,
#  'tp': 3443,
#  'tn': 39794,
#  'fp': 16689,
#  'fn': 1517,
#  'acc': 0.7036928535390524,
#  'bal_acc': 0.6993418962628208,
#  'prec': 0.17102125968607193,
#  'rec': 0.6941532258064517,
#  'spec': 0.7045305667191899,
#  'f1': 0.2744300972421489,
#  'roc_auc': 0.7628665569086446,
#  'train_roc_auc': 0.7557983686938431,
#  'pr_roc_auc': 0.23600742119957863}

# %%
# Random CV method
apps_cv_random = pd.read_csv("data/apps_cv_random.csv")
apps_holdout_random = pd.read_csv("data/apps_holdout_random.csv")
target_col = 'TARGET'
feature_cols = [col for col in apps_cv_random.columns if col not in 
                [target_col, 'SK_ID_CURR', 'fold', 'neighbors_target_mean_500' , 'AGE_INT', 'DAYS_BIRTH', 'CODE_GENDER_M', 'CODE_GENDER_XNA', 'NAME_FAMILY_STATUS_Previously Married', 'NAME_FAMILY_STATUS_Single']]
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100],
    "loss": ["hinge", "squared_hinge"]
}

wide_search_results = grid_search_SVC(apps_cv_random, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1/12 (  8.3% in 1.0 mins) | Best ROC-AUC: 0.7567 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/12 ( 16.7% in 8.6 mins) | Best ROC-AUC: 0.7567 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/12 ( 25.0% in 11.1 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.01, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 4/12 ( 33.3% in 17.8 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.01, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/12 ( 41.7% in 23.2 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/12 ( 50.0% in 30.9 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 7/12 ( 58.3% in 37.2 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/12 ( 66.7% in 44.2 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/12 ( 75.0% in 51.7 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 10/12 ( 83.3% in 59.4 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/12 ( 91.7% in 66.6 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/12 (100.0% in 74.0 mins) | Best ROC-AUC: 0.7570 | Best Params: {'C': 0.1, 'loss': 'hinge'}

# %%
wide_search_results
# Out:
#                                    params  mean_roc_auc   mean_f1  mean_acc  \
# 0             {'C': 0.1, 'loss': 'hinge'}      0.756992  0.267886  0.699470
# 1            {'C': 0.01, 'loss': 'hinge'}      0.756830  0.267589  0.698770
# 2    {'C': 0.01, 'loss': 'squared_hinge'}      0.756820  0.267741  0.699295
# 3           {'C': 0.001, 'loss': 'hinge'}      0.756717  0.266931  0.697468
# 4   {'C': 0.001, 'loss': 'squared_hinge'}      0.756675  0.267401  0.698929
# 5     {'C': 0.1, 'loss': 'squared_hinge'}      0.756660  0.269067  0.703205
# 6               {'C': 1, 'loss': 'hinge'}      0.749659  0.266898  0.709272
# 7       {'C': 1, 'loss': 'squared_hinge'}      0.733219  0.278840  0.799061
# 8      {'C': 10, 'loss': 'squared_hinge'}      0.603407  0.135945  0.864149
# 9              {'C': 10, 'loss': 'hinge'}      0.586375  0.121858  0.871481
# 10    {'C': 100, 'loss': 'squared_hinge'}      0.582878  0.113663  0.870260
# 11            {'C': 100, 'loss': 'hinge'}      0.562131  0.107044  0.856715
#
#     mean_bal_acc  mean_prec  mean_rec
# 0       0.692082   0.166613  0.683271
# 1       0.691957   0.166350  0.683831
# 2       0.691937   0.166506  0.683162
# 3       0.691550   0.165803  0.684491
# 4       0.691575   0.166264  0.682805
# 5       0.692107   0.167790  0.678874
# 6       0.685664   0.167446  0.657532
# 7       0.654478   0.196618  0.482168
# 8       0.534937   0.140985  0.142560
# 9       0.524952   0.141672  0.111985
# 10      0.524255   0.138125  0.111947
# 11      0.514993   0.113359  0.107726

# %%
powers = np.arange(-3, -1, 0.1)
grid_values = [10**x for x in powers]

param_grid = {
    "C": grid_values,
    "loss": ["hinge"]
}

search_results2 = grid_search_SVC(apps_cv_random, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1/20 (  5.0% in 0.9 mins) | Best ROC-AUC: 0.7567 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/20 ( 10.0% in 1.9 mins) | Best ROC-AUC: 0.7567 | Best Params: {'C': 0.0012589254117941675, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/20 ( 15.0% in 3.0 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.001584893192461114, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 4/20 ( 20.0% in 4.2 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.0019952623149688807, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/20 ( 25.0% in 5.4 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.002511886431509582, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/20 ( 30.0% in 6.8 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.0031622776601683824, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 7/20 ( 35.0% in 8.4 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.0031622776601683824, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/20 ( 40.0% in 10.1 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.00501187233627273, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/20 ( 45.0% in 12.0 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.00501187233627273, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 10/20 ( 50.0% in 14.3 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.00501187233627273, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/20 ( 55.0% in 17.4 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.010000000000000021, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/20 ( 60.0% in 20.3 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.010000000000000021, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 13/20 ( 65.0% in 23.7 mins) | Best ROC-AUC: 0.7568 | Best Params: {'C': 0.010000000000000021, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 14/20 ( 70.0% in 27.4 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.01995262314968885, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 15/20 ( 75.0% in 31.3 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.01995262314968885, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 16/20 ( 80.0% in 35.9 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.03162277660168389, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 17/20 ( 85.0% in 40.6 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.03981071705534985, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 18/20 ( 90.0% in 45.8 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.03981071705534985, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 19/20 ( 95.0% in 51.2 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.03981071705534985, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 20/20 (100.0% in 56.9 mins) | Best ROC-AUC: 0.7569 | Best Params: {'C': 0.03981071705534985, 'loss': 'hinge'}

# %%
search_results2
# Out:
#                                            params  mean_roc_auc   mean_f1  \
# 0     {'C': 0.03981071705534985, 'loss': 'hinge'}      0.756918  0.267692
# 1     {'C': 0.03162277660168389, 'loss': 'hinge'}      0.756883  0.267520
# 2     {'C': 0.01995262314968885, 'loss': 'hinge'}      0.756877  0.267410
# 3    {'C': 0.025118864315095874, 'loss': 'hinge'}      0.756861  0.267333
# 4    {'C': 0.010000000000000021, 'loss': 'hinge'}      0.756849  0.267437
# 5    {'C': 0.015848931924611172, 'loss': 'hinge'}      0.756845  0.267499
# 6    {'C': 0.012589254117941701, 'loss': 'hinge'}      0.756843  0.267504
# 7     {'C': 0.07943282347242846, 'loss': 'hinge'}      0.756837  0.267724
# 8     {'C': 0.00501187233627273, 'loss': 'hinge'}      0.756833  0.267510
# 9     {'C': 0.00794328234724283, 'loss': 'hinge'}      0.756830  0.267422
# 10   {'C': 0.006309573444801942, 'loss': 'hinge'}      0.756824  0.267428
# 11  {'C': 0.0031622776601683824, 'loss': 'hinge'}      0.756804  0.267354
# 12   {'C': 0.003981071705534978, 'loss': 'hinge'}      0.756795  0.267407
# 13   {'C': 0.002511886431509582, 'loss': 'hinge'}      0.756795  0.267372
# 14     {'C': 0.0501187233627274, 'loss': 'hinge'}      0.756790  0.267575
# 15  {'C': 0.0019952623149688807, 'loss': 'hinge'}      0.756770  0.267297
# 16   {'C': 0.001584893192461114, 'loss': 'hinge'}      0.756761  0.267186
# 17    {'C': 0.06309573444801955, 'loss': 'hinge'}      0.756752  0.267441
# 18  {'C': 0.0012589254117941675, 'loss': 'hinge'}      0.756741  0.267041
# 19                  {'C': 0.001, 'loss': 'hinge'}      0.756721  0.266931
#
#     mean_acc  mean_bal_acc  mean_prec  mean_rec
# 0   0.699063      0.691981   0.166447  0.683534
# 1   0.698864      0.691800   0.166324  0.683374
# 2   0.698783      0.691663   0.166251  0.683171
# 3   0.698669      0.691600   0.166191  0.683170
# 4   0.698669      0.691762   0.166251  0.683524
# 5   0.698742      0.691825   0.166296  0.683576
# 6   0.698750      0.691830   0.166300  0.683577
# 7   0.699784      0.691678   0.166562  0.682011
# 8   0.698673      0.691882   0.166292  0.683783
# 9   0.698648      0.691751   0.166239  0.683526
# 10  0.698587      0.691787   0.166235  0.683675
# 11  0.698477      0.691728   0.166177  0.683677
# 12  0.698534      0.691781   0.166215  0.683727
# 13  0.698372      0.691810   0.166173  0.683984
# 14  0.698994      0.691824   0.166372  0.683272
# 15  0.698233      0.691757   0.166112  0.684033
# 16  0.698018      0.691687   0.166020  0.684136
# 17  0.698746      0.691732   0.166262  0.683368
# 18  0.697749      0.691587   0.165902  0.684237
# 19  0.697468      0.691552   0.165802  0.684493

# %% [markdown]
# We found the best value of `C` to be 10^-1.4, with 10^-1.5 in a close second. Hinge loss was still better than squared hinge

# %%
# Multi-stratified CV method
apps_cv_multi = pd.read_csv("data/apps_cv_multi.csv")
apps_holdout_multi = pd.read_csv("data/apps_holdout_multi.csv")
target_col = 'TARGET'
feature_cols = [col for col in apps_cv_multi.columns if col not in 
                [target_col, 'SK_ID_CURR', 'fold', 'neighbors_target_mean_500' , 'AGE_INT', 'DAYS_BIRTH', 'CODE_GENDER_M', 'CODE_GENDER_XNA', 'NAME_FAMILY_STATUS_Previously Married', 'NAME_FAMILY_STATUS_Single']]
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100],
    "loss": ["hinge", "squared_hinge"]
}

wide_search_results = grid_search_SVC(apps_cv_multi, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 1/12 (  8.3% in 0.9 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/12 ( 16.7% in 7.8 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.001, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/12 ( 25.0% in 10.2 mins) | Best ROC-AUC: 0.7560 | Best Params: {'C': 0.01, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 4/12 ( 33.3% in 16.8 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.01, 'loss': 'squared_hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/12 ( 41.7% in 22.1 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/12 ( 50.0% in 28.8 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 7/12 ( 58.3% in 34.8 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/12 ( 66.7% in 41.6 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/12 ( 75.0% in 48.7 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 10/12 ( 83.3% in 56.9 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/12 ( 91.7% in 65.0 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/12 (100.0% in 72.8 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.1, 'loss': 'hinge'}

# %%
wide_search_results
# Out:
#                                    params  mean_roc_auc   mean_f1  mean_acc  \
# 0             {'C': 0.1, 'loss': 'hinge'}      0.756183  0.267588  0.698647
# 1     {'C': 0.1, 'loss': 'squared_hinge'}      0.756166  0.268697  0.702357
# 2    {'C': 0.01, 'loss': 'squared_hinge'}      0.756120  0.267153  0.698687
# 3            {'C': 0.01, 'loss': 'hinge'}      0.755990  0.266854  0.697219
# 4           {'C': 0.001, 'loss': 'hinge'}      0.755873  0.266311  0.695774
# 5   {'C': 0.001, 'loss': 'squared_hinge'}      0.755843  0.266743  0.698053
# 6               {'C': 1, 'loss': 'hinge'}      0.751548  0.265204  0.698899
# 7       {'C': 1, 'loss': 'squared_hinge'}      0.733508  0.280579  0.802081
# 8      {'C': 10, 'loss': 'squared_hinge'}      0.629641  0.164940  0.852526
# 9     {'C': 100, 'loss': 'squared_hinge'}      0.589629  0.147128  0.846085
# 10             {'C': 10, 'loss': 'hinge'}      0.570843  0.117295  0.863315
# 11            {'C': 100, 'loss': 'hinge'}      0.569524  0.103494  0.871356
#
#     mean_bal_acc  mean_prec  mean_rec
# 0       0.690972   0.166460  0.681819
# 1       0.690898   0.167599  0.677233
# 2       0.690258   0.166220  0.680206
# 3       0.690494   0.165854  0.682474
# 4       0.690329   0.165355  0.683835
# 5       0.689913   0.165903  0.680206
# 6       0.686995   0.165182  0.672799
# 7       0.654125   0.199018  0.477675
# 8       0.548622   0.155944  0.186196
# 9       0.536706   0.132592  0.167749
# 10      0.521677   0.122652  0.114246
# 11      0.522365   0.121922  0.106168

# %%
powers = np.arange(-3, 0, 0.1)
grid_values = [10**x for x in powers]

param_grid = {
    "C": grid_values,
    "loss": ["hinge"]
}

search_results2 = grid_search_SVC(apps_cv_multi, feature_cols, target_col, param_grid)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2/30 (  6.7% in 1.8 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.0012589254117941675, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3/30 ( 10.0% in 2.8 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.001584893192461114, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 5/30 ( 16.7% in 5.1 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.001584893192461114, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 6/30 ( 20.0% in 6.4 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.0031622776601683824, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 8/30 ( 26.7% in 9.6 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.00501187233627273, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 9/30 ( 30.0% in 11.4 mins) | Best ROC-AUC: 0.7559 | Best Params: {'C': 0.006309573444801942, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 11/30 ( 36.7% in 16.0 mins) | Best ROC-AUC: 0.7560 | Best Params: {'C': 0.010000000000000021, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 12/30 ( 40.0% in 18.8 mins) | Best ROC-AUC: 0.7560 | Best Params: {'C': 0.012589254117941701, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 14/30 ( 46.7% in 25.3 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.01995262314968885, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 15/30 ( 50.0% in 29.3 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.025118864315095874, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 17/30 ( 56.7% in 38.3 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.025118864315095874, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 18/30 ( 60.0% in 43.1 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.025118864315095874, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 20/30 ( 66.7% in 53.3 mins) | Best ROC-AUC: 0.7561 | Best Params: {'C': 0.06309573444801955, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 21/30 ( 70.0% in 58.6 mins) | Best ROC-AUC: 0.7562 | Best Params: {'C': 0.10000000000000041, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 23/30 ( 76.7% in 69.6 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 24/30 ( 80.0% in 75.2 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 26/30 ( 86.7% in 86.5 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 27/30 ( 90.0% in 92.2 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 29/30 ( 96.7% in 103.9 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 30/30 (100.0% in 109.9 mins) | Best ROC-AUC: 0.7563 | Best Params: {'C': 0.15848931924611206, 'loss': 'hinge'}

# %%
search_results2
# Out:
#                                            params  mean_roc_auc   mean_f1  \
# 0     {'C': 0.15848931924611206, 'loss': 'hinge'}      0.756335  0.267729
# 1      {'C': 0.1995262314968889, 'loss': 'hinge'}      0.756278  0.267526
# 2     {'C': 0.10000000000000041, 'loss': 'hinge'}      0.756204  0.267138
# 3     {'C': 0.06309573444801955, 'loss': 'hinge'}      0.756150  0.267289
# 4    {'C': 0.025118864315095874, 'loss': 'hinge'}      0.756097  0.267236
# 5     {'C': 0.03162277660168389, 'loss': 'hinge'}      0.756097  0.267076
# 6      {'C': 0.0501187233627274, 'loss': 'hinge'}      0.756077  0.267218
# 7     {'C': 0.07943282347242846, 'loss': 'hinge'}      0.756076  0.267162
# 8     {'C': 0.03981071705534985, 'loss': 'hinge'}      0.756076  0.267215
# 9     {'C': 0.12589254117941726, 'loss': 'hinge'}      0.756068  0.267503
# 10    {'C': 0.01995262314968885, 'loss': 'hinge'}      0.756063  0.267193
# 11   {'C': 0.015848931924611172, 'loss': 'hinge'}      0.756060  0.267061
# 12    {'C': 0.25118864315095923, 'loss': 'hinge'}      0.756028  0.267670
# 13   {'C': 0.012589254117941701, 'loss': 'hinge'}      0.756006  0.266879
# 14   {'C': 0.010000000000000021, 'loss': 'hinge'}      0.755993  0.266857
# 15    {'C': 0.00794328234724283, 'loss': 'hinge'}      0.755970  0.266754
# 16   {'C': 0.006309573444801942, 'loss': 'hinge'}      0.755950  0.266807
# 17    {'C': 0.00501187233627273, 'loss': 'hinge'}      0.755930  0.266732
# 18  {'C': 0.0031622776601683824, 'loss': 'hinge'}      0.755909  0.266781
# 19   {'C': 0.001584893192461114, 'loss': 'hinge'}      0.755902  0.266598
# 20   {'C': 0.002511886431509582, 'loss': 'hinge'}      0.755900  0.266699
# 21  {'C': 0.0019952623149688807, 'loss': 'hinge'}      0.755897  0.266596
# 22   {'C': 0.003981071705534978, 'loss': 'hinge'}      0.755894  0.266756
# 23  {'C': 0.0012589254117941675, 'loss': 'hinge'}      0.755888  0.266560
# 24                  {'C': 0.001, 'loss': 'hinge'}      0.755879  0.266387
# 25    {'C': 0.31622776601683955, 'loss': 'hinge'}      0.755659  0.268028
# 26    {'C': 0.39810717055349937, 'loss': 'hinge'}      0.755494  0.267528
# 27      {'C': 0.501187233627275, 'loss': 'hinge'}      0.754813  0.267239
# 28     {'C': 0.6309573444801969, 'loss': 'hinge'}      0.753215  0.265025
# 29     {'C': 0.7943282347242863, 'loss': 'hinge'}      0.751986  0.264121
#
#     mean_acc  mean_bal_acc  mean_prec  mean_rec
# 0   0.698866      0.691068   0.166577  0.681768
# 1   0.698765      0.690806   0.166444  0.681315
# 2   0.698309      0.690420   0.166161  0.681013
# 3   0.697670      0.690969   0.166160  0.682978
# 4   0.697678      0.690882   0.166132  0.682776
# 5   0.697430      0.690747   0.166007  0.682776
# 6   0.697695      0.690845   0.166124  0.682676
# 7   0.697585      0.690808   0.166078  0.682726
# 8   0.697691      0.690843   0.166121  0.682676
# 9   0.698146      0.691067   0.166350  0.682625
# 10  0.697320      0.690986   0.166060  0.683431
# 11  0.697385      0.690746   0.165993  0.682827
# 12  0.698057      0.691386   0.166428  0.683431
# 13  0.697304      0.690494   0.165880  0.682373
# 14  0.697247      0.690486   0.165859  0.682424
# 15  0.697109      0.690388   0.165783  0.682373
# 16  0.697145      0.690454   0.165818  0.682474
# 17  0.697052      0.690380   0.165762  0.682424
# 18  0.696861      0.690552   0.165765  0.683028
# 19  0.696332      0.690517   0.165591  0.683583
# 20  0.696665      0.690515   0.165692  0.683179
# 21  0.696462      0.690450   0.165607  0.683280
# 22  0.696954      0.690465   0.165763  0.682726
# 23  0.696161      0.690539   0.165546  0.683835
# 24  0.695803      0.690436   0.165401  0.684036
# 25  0.699904      0.691058   0.166879  0.680508
# 26  0.701051      0.689705   0.166755  0.676174
# 27  0.700441      0.689535   0.166513  0.676529
# 28  0.695656      0.688288   0.164626  0.679501
# 29  0.694741      0.687261   0.163997  0.678342

# %% [markdown]
# We found the best value of `C` to be 10^-0.8, although the hyperparameter C appears to be quite unstable with regards to optimizing ROC-AUC. 10^-1.5 is 5th and 10^-1.4 is 8th
